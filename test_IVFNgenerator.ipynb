# %%
import GeneratorFunc as gf

# %%
def test_func(x,*p):
    return 1/(p[0]*x+p[1])

# %%
x = gf.IVFNGenerator(3,True)
x.MFgeneratorSetting(test_func,[2,3],[4,7])
x.NMFgeneratorSetting(test_func,[1,4],[6,3])
x.setVariable(0,10,1000)
x.generatorFunc()
# Out:
# Membership function:
# Function: test_func
# Lower limit membership parameter: [2 3]
# Upper limit membership parameter: [4 7]
# Non-Membership function:
# Function: test_func
# Lower limit membership parameter: [1 4]
# Upper limit membership parameter: [6 3]

# %%
x.MF_NMF_Plot()

# %%
x.generator(0.2,4.1)
# Out:
# QRungIVFN(Q=3):(
#  MD: [0.1069,0.2506]
#  NMD:[0.0204,0.052])

# %%
t = gf.IVFNGenerator(2)
t.MFgeneratorSetting('gaussmf',(0.6,0.3),(0.5,0.5))
t.NMFgeneratorSetting('gaussmf',(0.5,0.4),(0.3,0.6))
t.setVariable(0,1,100)
t.generatorFunc()
# Out:
# Membership function:
# Function: gaussmf
# Lower limit membership parameter: (0.6, 0.3)
# Upper limit membership parameter: (0.5, 0.5)
# Non-Membership function:
# Function: gaussmf
# Lower limit membership parameter: (0.5, 0.4)
# Upper limit membership parameter: (0.3, 0.6)

# %%
t.MF_NMF_Plot()

# %%
t.generator(0.77,0.45)
# Out:
# QRungIVFN(Q=2):(
#  MD: [0.2578,0.7163]
#  NMD:[0.4629,0.5344])
