# %%
import xmlrpc.client

import numpy as np
from fuzzgener.memfunc import memfunc

# %%
s = memfunc('gaussmf',[[0.443,0.575],[0.395,0.676],[0.335,0.871]])

# %%
s.setvariable(-3,3,100)

# %%
s.plot(figsize=(5,3))

# %%
s
# Out:
# Function 1: gaussmf, parameter: [0.443, 0.575]
# Function 2: gaussmf, parameter: [0.395, 0.676]
# Function 3: gaussmf, parameter: [0.335, 0.871]

# %%
s.maxmd_in_interval()
# Out:
# array([0.99979844, 0.99999877, 0.99999817])

# %%
s.minmd_in_interval()
# Out:
# array([1.63828526e-08, 3.33448295e-06, 6.55336881e-04])

# %%
def test_func(x,*p):
    return 1/(p[0]*x+p[1])

# %%
t = memfunc(test_func,[0.34,0.77],custom=True)

# %%
t.setvariable(0,1,100)

# %%
t.plot()
